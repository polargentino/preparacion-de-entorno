# %% [markdown]
# # 🚀 Guía de Inicio: Entorno de Desarrollo Web
#
# Esta guía te ayudará a configurar las herramientas básicas para comenzar a programar: **Visual Studio Code**, **Git** y **GitHub**. Sigue cada paso con atención.
#
# ---
#
# ## 1. Instalación y Configuración de Visual Studio Code (VS Code)
#
# Visual Studio Code es el editor de código más utilizado en la industria.
#
# 1. **Descarga:** Ve a [code.visualstudio.com](https://code.visualstudio.com/) y descarga la versión para tu sistema operativo.
# 2. **Instalación:** Ejecuta el instalador. **Importante:** Durante la instalación en Windows, marca las casillas que dicen *"Agregar la acción 'Abrir con Code'"*.
# 3. **Configurar en Español:**
# * Abre VS Code.
# * Presiona `Ctrl + Shift + X` (Extensiones).
# * Busca **"Spanish Language Pack"** e instálalo.
# * Presiona `Ctrl + Shift + P`, escribe `Configure Display Language`, selecciona `es` y reinicia el programa.
#
#
# 4. **Instalar Live Server:**
# * En el panel de extensiones (`Ctrl + Shift + X`), busca **"Live Server"** (de Ritwick Dey).
# * Haz clic en **Install**. Esto nos permitirá ver los cambios en tiempo real.
#
#
#
# ---
#
# ## 2. Creación del Primer Proyecto
#
# 1. **Carpeta de trabajo:** Ve a tu **Escritorio**, haz clic derecho y crea una carpeta nueva llamada `mi-primer-proyecto`.
# 2. **Abrir en VS Code:**
# * Vuelve a VS Code.
# * Ve a **Archivo > Abrir carpeta** y selecciona la carpeta que creaste en el escritorio.
#
#
# 3. **Crear el archivo HTML:**
# * En el panel de la izquierda (Explorador), haz clic en el icono de **Nuevo archivo**.
# * Nómbralo exactamente como `index.html`.
# * Escribe `!` y presiona `Tab` o `Enter` para generar la estructura básica de HTML5.
#
#
# 4. **Prueba de Live Server:**
# * Escribe un `<h1>Hola Mundo</h1>` dentro del `<body>`.
# * Haz clic derecho sobre el código y selecciona **"Open with Live Server"**.
# * **Comprobación:** Se debería abrir tu navegador mostrando el mensaje.
#
#
#
# ---
#
# ## 3. Instalación de Git y Uso de la Terminal
#
# Git es el sistema que controla las versiones de nuestro código.
#
# 1. **Instalación:** Descárgalo de [git-scm.com](https://git-scm.com/) e instálalo con las opciones por defecto.
# 2. **Configuración de Terminal en VS Code:**
# * Abre la terminal integrada en VS Code con `Ctrl + ñ` (o Terminal > Nueva terminal).
# * Asegúrate de que diga **bash** en el desplegable de la derecha.
#
#
# 3. **Comandos Básicos de Bash (Práctica):**
# * `pwd`: Muestra en qué carpeta estás posicionado.
# * `ls`: Lista los archivos de la carpeta actual (deberías ver `index.html`).
# * `mkdir assets`: Crea una carpeta llamada "assets".
# * `clear`: Limpia la pantalla de la terminal.
#
#
#
# ---
#
# ## 4. GitHub y Publicación del Proyecto
#
# ### Paso A: Crear cuenta y repositorio
#
# 1. Crea una cuenta en [github.com](https://github.com/) y verifica tu correo.
# 2. Haz clic en el botón **"New"** (Nuevo repositorio).
# 3. Nombre del repositorio: `mi-proyecto-web`.
# 4. Déjalo como **Public** y no marques ninguna casilla adicional. Haz clic en **Create repository**.
#
# ### Paso B: Subir el código (Comandos de Git)
#
# Regresa a la terminal de VS Code y escribe estos comandos uno por uno:
#
# 1. **Inicializar:** `git init`
# 2. **Configurar identidad** (Solo la primera vez):
# * `git config --global user.email "tu@email.com"`
# * `git config --global user.name "Tu Nombre"`
#
#
# 3. **Preparar archivos:** `git add .`
# 4. **Primer "guardado":** `git commit -m "Mi primer commit"`
# 5. **Vincular a GitHub:** Copia la línea que dice `git remote add origin...` de la página de GitHub y pégala en la terminal.
# 6. **Subir código:** `git push -u origin master` (o `main` según indique GitHub).
#
# ### Paso C: Publicar en la Web (GitHub Pages)
#
# 1. En tu repositorio de GitHub, ve a **Settings** (Configuración).
# 2. En el menú lateral, busca **Pages**.
# 3. En "Branch", selecciona **main** (o master) y la carpeta **/(root)**. Haz clic en **Save**.
# 4. **Comprobación:** En unos minutos, GitHub te dará un enlace (URL) donde tu `index.html` será visible para todo el mundo.
#
# ---
# ¡Excelente! Para que la primera experiencia con la terminal no sea solo escribir comandos sin sentido, aquí tienes una **Actividad de Práctica de Terminal (Bash)**. Puedes añadirla al final de la guía anterior para que los alumnos ganen confianza.
#
# ---
#
# ## 🛠️ Actividad Práctica: "Misión Terminal"
#
# El objetivo es manipular archivos y carpetas sin usar el ratón, solo la terminal de VS Code.
#
# ### Reto 1: Organización de archivos
#
# Escribe los siguientes comandos en orden y observa cómo cambia tu panel de archivos a la izquierda:
#
# 1. **Verificar ubicación:** `pwd`
# *(Asegúrate de que la ruta termine en tu carpeta de proyecto).*
# 2. **Crear estructura de carpetas:** `mkdir css js img`
# *(Esto creará tres carpetas: una para estilos, otra para scripts y una para imágenes).*
# 3. **Crear archivos desde la terminal:** `touch css/style.css js/script.js`
# *(Creamos los archivos directamente dentro de sus carpetas).*
# 4. **Listar para verificar:** `ls -R`
# *(Verás toda tu nueva estructura en pantalla).*
#
# ---
#
# ### Reto 2: Flujo de Trabajo Real (Git)
#
# Ahora que hemos creado carpetas nuevas, vamos a actualizar tu repositorio en GitHub:
#
# 1. **Ver el estado:** `git status`
# *(Verás las nuevas carpetas en rojo porque Git aún no las sigue).*
# 2. **Preparar cambios:** `git add .`
# 3. **Confirmar cambios:** `git commit -m "Estructura de carpetas inicial creada"`
# 4. **Sincronizar con la nube:** `git push`
#
# ---
#
# ## ✅ Lista de comprobación para el Alumno
#
# Antes de terminar la clase, asegúrate de cumplir con esto:
#
# * [ ] VS Code está en español.
# * [ ] Al cambiar el `<h1>` en HTML, el navegador se actualiza solo (Live Server).
# * [ ] El comando `ls` muestra tus archivos en la terminal.
# * [ ] Puedes ver tu archivo `index.html` entrando al enlace de **GitHub Pages** desde tu celular.
#
# ---

# %% [markdown]
#  he preparado un archivo `index.html` que funciona como una "guía interactiva". No solo contiene las etiquetas, sino que el texto explica para qué sirve cada una.
#
# Aquí tienes el código listo para copiar, pegar y guardar:
#
# ---
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Aprendiendo las etiquetas básicas</title>
#     <style>
#         body { font-family: sans-serif; line-height: 1.6; max-width: 800px; margin: auto; padding: 20px; background-color: #f4f4f4; }
#         section { background: white; padding: 20px; border-radius: 8px; margin-bottom: 20px; box-shadow: 0 2px 5px rgba(0,0,0,0.1); }
#         code { background: #eee; padding: 2px 5px; border-radius: 4px; color: #d63384; }
#     </style>
# </head>
# <body>
#
#     <header>
#         <h1>Estructura de una Página Web</h1>
#         <p>Esta es la etiqueta <code>&lt;header&gt;</code>, usada para encabezados.</p>
#     </header>
#
#     <nav>
#         <ul>
#             <li><a href="#titulos">Títulos</a></li>
#             <li><a href="#textos">Textos y Enlaces</a></li>
#             <li><a href="#multimedia">Multimedia</a></li>
#             <li><a href="#listas">Listas</a></li>
#         </ul>
#     </nav>
#
#     <main>
#         <section id="titulos">
#             <h2>1. Títulos (Headings)</h2>
#             <p>Los títulos van del <code>&lt;h1&gt;</code> al <code>&lt;h6&gt;</code> según su importancia.</p>
#             <h3>Este es un H3</h3>
#             <h4>Este es un H4</h4>
#         </section>
#
#         <section id="textos">
#             <h2>2. Textos y Enlaces</h2>
#             <p>La etiqueta <code>&lt;p&gt;</code> se usa para párrafos de texto.</p>
#             <p>Puedes usar <strong>negrita con la etiqueta strong</strong> o <em>cursiva con la etiqueta em</em>.</p>
#             <p>Para ir a otro sitio, usamos la etiqueta de enlace:
#                 <a href="https://www.google.com" target="_blank">Haz clic aquí para ir a Google</a>.
#             </p>
#         </section>
#
#         <section id="multimedia">
#             <h2>3. Imágenes y Multimedia</h2>
#             <p>Para mostrar una imagen usamos <code>&lt;img&gt;</code>:</p>
#             <img src="https://via.placeholder.com/300x150" alt="Imagen de ejemplo">
#             <p><small>Nota: La etiqueta img no tiene cierre automático.</small></p>
#         </section>
#
#         <section id="listas">
#             <h2>4. Listas</h2>
#             <h3>Lista desordenada (con viñetas):</h3>
#             <ul>
#                 <li>HTML</li>
#                 <li>CSS</li>
#                 <li>JavaScript</li>
#             </ul>
#
#             <h3>Lista ordenada (con números):</h3>
#             <ol>
#                 <li>Instalar VS Code</li>
#                 <li>Instalar Git</li>
#                 <li>Crear repositorio</li>
#             </ol>
#         </section>
#     </main>
#
#     <footer>
#         <p>&copy; 2026 - Guía elaborada para la clase de Diseño Web</p>
#     </footer>
#
# </body>
# </html>
#
# ```
#
# ---
#
# ### 💡 Sugerencia pedagógica para los alumnos:
#
# Una vez que peguen el código en su `index.html` y lo vean con **Live Server**,  realicen estos cambios para comprobar que entendieron:
#
# 1. **Cambiar el texto:** Que cambien el contenido del `<h1>` por su propio nombre.
# 2. **Añadir un enlace:** Que busquen una foto en internet, copien la URL y la peguen en el atributo `src` de la etiqueta `<img>`.
# 3. **Crear una lista:** Que añadan un nuevo ítem a la lista de "pasos" con el comando de Git que más les costó aprender.

# %% [markdown]
#  Los formularios son la base de la interacción (registros, contactos, encuestas) y las tablas son esenciales para mostrar datos estructurados.
#
# Aquí tienes la actualización para agregar al `<main>` de tu archivo `index.html`. He incluido comentarios pedagógicos para que los alumnos entiendan qué hace cada atributo especial (como `type`, `placeholder` o `name`).
#
# ---
#
# ### 5. Tablas y Formularios
#
# Copia este bloque después de la última `<section>` de tu archivo:
#
# ```html
#         <section id="tablas">
#             <h2>5. Tablas de Datos</h2>
#             <p>Usamos <code>&lt;table&gt;</code> para organizar información en filas y columnas.</p>
#             <table border="1" style="width:100%; border-collapse: collapse; text-align: left;">
#                 <thead>
#                     <tr style="background-color: #333; color: white;">
#                         <th>Herramienta</th>
#                         <th>Función Principal</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#                     <tr>
#                         <td>HTML</td>
#                         <td>Estructura del contenido</td>
#                     </tr>
#                     <tr>
#                         <td>CSS</td>
#                         <td>Diseño y apariencia</td>
#                     </tr>
#                     <tr>
#                         <td>Git</td>
#                         <td>Control de versiones</td>
#                     </tr>
#                 </tbody>
#             </table>
#         </section>
#
#         <section id="formularios">
#             <h2>6. Formularios (Interacción)</h2>
#             <p>Los formularios permiten que el usuario nos envíe información.</p>
#             <form>
#                 <div style="margin-bottom: 10px;">
#                     <label for="nombre">Nombre:</label><br>
#                     <input type="text" id="nombre" name="nombre" placeholder="Escribe tu nombre">
#                 </div>
#
#                 <div style="margin-bottom: 10px;">
#                     <label for="correo">Correo Electrónico:</label><br>
#                     <input type="email" id="correo" name="correo" required placeholder="tu@email.com">
#                 </div>
#
#                 <div style="margin-bottom: 10px;">
#                     <label>¿Qué herramienta te gusta más?</label><br>
#                     <input type="radio" id="html" name="fav" value="HTML"> <label for="html">HTML</label>
#                     <input type="radio" id="git" name="fav" value="Git"> <label for="git">Git</label>
#                 </div>
#
#                 <div style="margin-bottom: 10px;">
#                     <label for="comentario">Comentarios:</label><br>
#                     <textarea id="comentario" name="comentario" rows="3" style="width: 100%;"></textarea>
#                 </div>
#
#                 <button type="submit" style="background-color: #28a745; color: white; border: none; padding: 10px 20px; border-radius: 4px; cursor: pointer;">
#                     Enviar Datos
#                 </button>
#             </form>
#         </section>
#
# ```
#
# ---
#
# ### 👨‍🏫 Dinámica para la clase:
#
#
#
# 1. **El reto del "Hotfix"(actividades):**una vez que hayan agregado este código, utilicen la terminal para subir los cambios:
# * `git add .`
# * `git commit -m "Agregada sección de tablas y formularios"`
# * `git push`
#
#
# 2. **La comprobación final:** Que entren a su enlace de **GitHub Pages** y verifiquen que ya pueden ver el formulario online.

# %% [markdown]
# En esta parte aprenderán a integrar servicios de terceros (como Google y YouTube), lo cual es fundamental en el diseño web moderno.
#
# ---
#
# ### 6. Integración de Contenido Externo (Iframes)
#
# Copia este bloque al final de tu `<main>`, justo antes de que se cierre la etiqueta `</main>`:
#
# ```html
#         <section id="multimedia-externa">
#             <h2>7. Contenido Externo (Iframes)</h2>
#             <p>Usamos la etiqueta <code>&lt;iframe&gt;</code> para incrustar contenido de otros sitios web.</p>
#
#             <h3>Video de YouTube</h3>
#             <div style="aspect-ratio: 16/9;">
#                 <iframe width="100%" height="315" src="https://www.youtube.com/embed/dQw4w9WgXcQ"
#                     title="Reproductor de video de YouTube" frameborder="0"
#                     allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
#                     allowfullscreen></iframe>
#             </div>
#
#             <h3>Ubicación (Google Maps)</h3>
#             <div style="margin-top: 20px;">
#                 <iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3284.0167132768406!2d-58.3841507242598!3d-34.60373887295116!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x4aa421b4636831fd%3A0x6739b6999cc0e0!2sObelisco!5e0!3m2!1ses-419!2sar!4v1700000000000!5m2!1ses-419!2sar"
#                     width="100%" height="300" style="border:0;" allowfullscreen="" loading="lazy"></iframe>
#             </div>
#         </section>
#
# ```
#
# ---
#
# ### 📝 Desafío Final para los alumnos:
#
# ### Actividad de cierre para evaluar si comprendieron el flujo de trabajo completo:
#
# 1. **Personalización:** busquen un video en YouTube que les guste, hagan clic en **Compartir > Insertar** y copien solo el código del `<iframe>` para reemplazar el del ejercicio.
# 2. **La gran subida:** Una vez que tengan todo el archivo completo (títulos, listas, tablas, formularios e iframes), deben hacer el ciclo final de Git:
# * `git add .`
# * `git commit -m "Proyecto base de HTML finalizado"`
# * `git push`
#
#
# 3. **Entrega:** La tarea se entrega enviándote el link de su **GitHub Pages**.
#
# ---

# %% [markdown]
# Separar el contenido (HTML) de la presentación (CSS) es el momento en que los alumnos dejan de escribir código "sucio" y empiezan a trabajar como profesionales.
#
# Aquí tienes la guía para que  creen su primera **hoja de estilos externa**.
#
# ---
#
# ## 🎨 Guía: Separando la Estructura del Diseño
#
# ### 1. Crear el archivo CSS
#
# En VS Code, dentro de la carpeta `css` que creamos antes por terminal (o creando una nueva), crea un archivo llamado `style.css`.
#
# ### 2. Vincular el CSS con el HTML
#
# Para que el navegador sepa que debe aplicar los estilos, debemos "conectar" los archivos.
#
# **Acción:** Dentro de tu `index.html`, busca la etiqueta `<head>` y, justo antes de que se cierre (`</head>`), pega esta línea:
#
# ```html
# <link rel="stylesheet" href="css/style.css">
#
# ```
#
# > **Nota para los alumnos:** Asegúrate de que la ruta `css/style.css` sea correcta según dónde guardaste el archivo.
#
# ---
#
# ### 3. Escribir el Código CSS
#
# Abre tu archivo `style.css` y pega el siguiente código. He quitado los estilos que estaban dentro de las etiquetas HTML para que ahora todo se controle desde aquí:
#
# ```css
# /* 1. Estilos Globales */
# body {
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     line-height: 1.6;
#     background-color: #f0f2f5;
#     color: #333;
#     margin: 0;
#     padding: 20px;
# }
#
# /* 2. Encabezado y Navegación */
# header {
#     background-color: #2c3e50;
#     color: white;
#     padding: 2rem;
#     text-align: center;
#     border-radius: 8px 8px 0 0;
# }
#
# nav ul {
#     background: #34495e;
#     padding: 10px;
#     list-style: none;
#     display: flex;
#     justify-content: center;
#     gap: 20px;
# }
#
# nav a {
#     color: white;
#     text-decoration: none;
#     font-weight: bold;
# }
#
# nav a:hover {
#     color: #3498db;
# }
#
# /* 3. Secciones */
# section {
#     background: white;
#     padding: 25px;
#     margin-top: 20px;
#     border-radius: 8px;
#     box-shadow: 0 4px 6px rgba(0,0,0,0.1);
# }
#
# h2 {
#     color: #2c3e50;
#     border-bottom: 2px solid #3498db;
#     padding-bottom: 10px;
# }
#
# /* 4. Tablas */
# table {
#     width: 100%;
#     border-collapse: collapse;
#     margin: 20px 0;
# }
#
# th, td {
#     border: 1px solid #ddd;
#     padding: 12px;
#     text-align: left;
# }
#
# th {
#     background-color: #3498db;
#     color: white;
# }
#
# /* 5. Formularios */
# input, textarea {
#     width: 100%;
#     padding: 10px;
#     margin-top: 5px;
#     border: 1px solid #ccc;
#     border-radius: 4px;
#     box-sizing: border-box; /* Muy importante para el ancho */
# }
#
# button {
#     background-color: #27ae60;
#     color: white;
#     border: none;
#     padding: 12px 20px;
#     border-radius: 4px;
#     cursor: pointer;
#     font-size: 16px;
#     transition: background 0.3s;
# }
#
# button:hover {
#     background-color: #219150;
# }
#
# ```
#
# ---
#
# ### 4. Limpieza (Refactorización)
#
# Ahora vuelve al `index.html` y **borren todos los atributos `style="..."**` que pusimos en los pasos anteriores.
#
# **Comprobación:** Si el archivo CSS está bien vinculado, la página debería verse mucho mejor que antes, incluso habiendo borrado los estilos del HTML.
#
# ---
#
# ### 🚀 El toque final con Git
#
# Para cerrar la clase, nada mejor que actualizar su portafolio:
#
# 1. `git add .`
# 2. `git commit -m "Migración de estilos a archivo CSS externo"`
# 3. `git push`
#
# ¿Te gustaría que preparemos una guía sobre **Flexbox** para que aprendan a acomodar los elementos (como las secciones o el menú) de forma más profesional y moderna?

# %% [markdown]
# Un buen `README.md` es la cara de cualquier proyecto en GitHub; ayuda a los alumnos a documentar su progreso y a que otros entiendan qué herramientas utilizaron.
#
# Aquí tienes el contenido para el archivo **README.md**. creen en la carpeta raíz de su proyecto (al mismo nivel que el `index.html`).
#
# ---
#
#
# # 🌐 Mi Primer Proyecto de Diseño Web
#
# ¡Bienvenido/a a mi primer repositorio! Este proyecto es el resultado de mis primeras clases de diseño web, donde aprendí a configurar un entorno de desarrollo profesional y a estructurar contenido utilizando HTML5 y CSS3.
#
# ## 🛠️ Herramientas Utilizadas
#
# En este proceso configuramos y aprendimos a usar las siguientes tecnologías:
#
# * **Visual Studio Code**: Mi editor de código principal, configurado con:
#     * Idioma: Español.
#     * Extensión **Live Server** para visualización en tiempo real.
# * **Git**: Sistema de control de versiones para registrar mis cambios.
# * **GitHub**: Plataforma para alojar el código y publicar el sitio mediante **GitHub Pages**.
# * **Bash (Terminal)**: Uso de comandos básicos para gestionar archivos y carpetas.
#
# ## 📚 Conceptos Aprendidos
#
# ### 1. Estructura HTML5
# He trabajado con las etiquetas más importantes del lenguaje:
# - **Estructura semántica**: `<header>`, `<nav>`, `<main>`, `<section>` y `<footer>`.
# - **Contenido**: Títulos (`<h1>` - `<h6>`), párrafos (`<p>`), enlaces (`<a>`) e imágenes (`<img>`).
# - **Organización**: Listas ordenadas y desordenadas.
# - **Datos y Formularios**: Creación de tablas y formularios de contacto con diferentes tipos de `input`.
# - **Multimedia**: Incrustación de videos y mapas mediante `<iframe>`.
#
# ### 2. Estilos con CSS3
# - Implementación de **CSS Externo** para mantener el código limpio.
# - Uso de selectores, manejo de colores, tipografías y bordes.
# - Comprensión del **Modelo de Caja (Box Model)**.
#
#
#
# ### 3. Control de Versiones con Git
# Manejo de la terminal para el flujo de trabajo básico:
# 1. `git status` (Ver estado)
# 2. `git add .` (Preparar cambios)
# 3. `git commit -m "mensaje"` (Guardar cambios localmente)
# 4. `git push` (Subir cambios a la nube)
#
# ## 🚀 Demo
# Puedes ver este proyecto en vivo a través de GitHub Pages haciendo clic en el siguiente enlace:
# *(Nota: Alumno, pega aquí tu link de GitHub Pages)*
#
# https://github.com/polargentino/preparacion-de-entorno/blob/main/README.md
# ---
# *Guía realizada bajo la supervisión del docente de Diseño Web.*
#
#
#
# ---
#
# ### 🎓 Instrucciones para los alumnos:
#
# Una vez que hayan creado el archivo y pegado el contenido anterior, hagan lo siguiente para verlo reflejado en su perfil de GitHub:
#
# 1. **Terminal:** Ejecutar la secuencia de comandos que ya conocen:
# * `git add README.md` (o `git add .`)
# * `git commit -m "Agregado archivo de documentación README"`
# * `git push`
#
#
# 2. **Verificación:** Entrar a su repositorio en la web de GitHub. Verán que ahora, debajo de la lista de archivos, aparece toda la información bien presentada.

# %% [markdown]
# Para que no se les mezcle con el contenido anterior, crear un **"Laboratorio de Flexbox"** desde cero es la mejor forma de que vean cómo se comportan las cajas sin distracciones.
#
# Aquí tienes el código para ambos archivos. Están diseñados para que el resultado sea visualmente atractivo y muy fácil de entender.
#
# ---
#
# ## 📄 Archivo 1: `index-2.html`
#
# Creen este archivo en la raíz de la carpeta del proyecto.
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Laboratorio de Flexbox</title>
#     <link rel="stylesheet" href="css/style-2.css">
# </head>
# <body>
#
#     <header>
#         <h1>Laboratorio de Flexbox</h1>
#         <p>Aprende a alinear elementos de forma profesional</p>
#     </header>
#
#     <main>
#         <section>
#             <h2>1. Alineación Horizontal (justify-content)</h2>
#             <p>Distribuye el espacio entre los elementos.</p>
#             <div class="contenedor contenedor-horizontal">
#                 <div class="caja roja">1</div>
#                 <div class="caja azul">2</div>
#                 <div class="caja verde">3</div>
#             </div>
#         </section>
#
#         <section>
#             <h2>2. Alineación Vertical (align-items)</h2>
#             <p>Alinea los elementos dentro de un contenedor con altura.</p>
#             <div class="contenedor contenedor-vertical">
#                 <div class="caja roja">A</div>
#                 <div class="caja azul">B</div>
#                 <div class="caja verde">C</div>
#             </div>
#         </section>
#
#         <section>
#             <h2>3. Salto de Línea (flex-wrap)</h2>
#             <p>Útil para galerías de fotos o tarjetas que deben bajar si no hay espacio.</p>
#             <div class="contenedor contenedor-wrap">
#                 <div class="caja">Item 1</div>
#                 <div class="caja">Item 2</div>
#                 <div class="caja">Item 3</div>
#                 <div class="caja">Item 4</div>
#                 <div class="caja">Item 5</div>
#                 <div class="caja">Item 6</div>
#             </div>
#         </section>
#     </main>
#
# </body>
# </html>
#
# ```
#
# ---
#
# ## 🎨 Archivo 2: `css/style-2.css`
#
# Este archivo debe ir dentro de la carpeta `css`.
#
# ```css
# /* Estilos base para que se vea limpio */
# body {
#     font-family: Arial, sans-serif;
#     background-color: #e9ecef;
#     margin: 0;
#     padding: 20px;
#     color: #333;
# }
#
# header {
#     text-align: center;
#     margin-bottom: 30px;
# }
#
# section {
#     background: white;
#     padding: 20px;
#     margin-bottom: 40px;
#     border-radius: 10px;
#     box-shadow: 0 4px 10px rgba(0,0,0,0.1);
# }
#
# /* Estilos de las "Cajas" del laboratorio */
# .contenedor {
#     background-color: #dee2e6;
#     border: 2px dashed #adb5bd;
#     padding: 10px;
#     border-radius: 5px;
# }
#
# .caja {
#     width: 80px;
#     height: 80px;
#     color: white;
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     font-weight: bold;
#     font-size: 1.2rem;
#     border-radius: 5px;
#     background-color: #6c757d; /* Color por defecto */
# }
#
# .roja { background-color: #e74c3c; }
# .azul { background-color: #3498db; }
# .verde { background-color: #2ecc71; }
#
# /* --- AQUÍ EMPIEZA LA MAGIA DE FLEXBOX --- */
#
# /* Ejercicio 1: Cambia justify-content por: flex-start, flex-end, center, space-between, space-around */
# .contenedor-horizontal {
#     display: flex;
#     justify-content: space-around;
# }
#
# /* Ejercicio 2: Cambia align-items por: flex-start, flex-end, center */
# .contenedor-vertical {
#     display: flex;
#     height: 250px; /* Altura para ver el movimiento vertical */
#     align-items: center;
#     justify-content: center; /* También centramos horizontal */
# }
#
# /* Ejercicio 3: Flex-wrap permite que los elementos bajen al faltar espacio */
# .contenedor-wrap {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 15px; /* Espacio entre cajas */
# }
#
# ```
#
# ---
#
# ### 👨‍🏫 Dinámica de Clase propuesta:
#
# 1. **El Juego de los Atributos:** en `style-2.css`, dentro de `.contenedor-horizontal`, cambien `space-around` por `space-between` y vean la diferencia con **Live Server**.
# 2. **El "Santo Grial" del Diseño:**Centrar algo perfectamente (vertical y horizontal) es tan fácil como poner:
# * `display: flex;`
# * `justify-content: center;`
# * `align-items: center;`
#
#
# 3. **Sincronización final:** Como siempre, al terminar:
# * `git add .`
# * `git commit -m "Agregado Laboratorio de Flexbox"`
# * `git push`

# %% [markdown]
# # 20/03/2026
#
# # 📸 Tarea: Mi Galería Fotográfica Profesional
#
# ¡Hola a todos! Después de ver cómo darle vida a una web con JavaScript y cómo manejar Flexbox, vamos a poner todo en práctica con un proyecto real. El objetivo es que aprendan a gestionar archivos multimedia (imágenes) y a publicar su propio contenido en la web.
#
# ## 🎯 Objetivo de la Tarea
# Deben construir una galería de fotos funcional utilizando **HTML** y **CSS (Flexbox)**. Primero haremos funcionar el ejemplo que les doy y luego lo personalizarán con sus propias fotos.
#
# ---
#
# ## 🛠️ Parte 1: El Desafío Técnico (Hacerlo funcionar)
#
# Creen dos archivos en su carpeta de proyecto: `index.html` y `styles.css`. Copien los códigos que les paso a continuación y asegúrense de que se vean correctamente usando **Live Server**.
#
# ### Código HTML de base:
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Photo Gallery</title>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#     <header class="header">
#         <h1>Mi Galería con Flexbox</h1>
#     </header>
#     <div class="gallery">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/1.jpg" alt="gatos">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/2.jpg" alt="gatos">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/3.jpg" alt="gatos">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/4.jpg" alt="gatos">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/5.jpg" alt="gatos">
#         <img src="https://cdn.freecodecamp.org/curriculum/css-photo-gallery/6.jpg" alt="gatos">
#     </div>
# </body>
# </html>
# ```
#
# ### Código CSS de base:
# ```css
# * {
#     box-sizing: border-box;
# }
#
# body {
#     margin: 0;
#     font-family: sans-serif;
#     background: #f5f6f7;
# }
#
# .header {
#     text-align: center;
#     text-transform: uppercase;
#     padding: 32px;
#     background-color: #0a0a23;
#     color: #fff;
#     border-bottom: 4px solid #fdb347;
# }
#
# .gallery {
#     display: flex;
#     flex-wrap: wrap;
#     justify-content: center;
#     align-items: center;
#     gap: 16px;
#     max-width: 1400px;
#     margin: 0 auto;
#     padding: 20px 10px;
# }
#
# .gallery img {
#     width: 100%;
#     max-width: 350px;
#     height: 300px;
#     object-fit: cover;
#     border-radius: 10px;
#     transition: transform 0.3s ease;
# }
#
# .gallery img:hover {
#     transform: scale(1.05);
#     box-shadow: 0 10px 20px rgba(0,0,0,0.2);
# }
# ```
#
# ---
#
# ## 🔍 Parte 2: Investigación (Teoría necesaria)
#
# Antes de subir sus fotos, deben investigar y responder en su archivo **README.md** lo siguiente:
#
# 1.  **Formatos de Imagen:** ¿Qué significan y cuándo conviene usar las siguientes extensiones?
#     * `.png`
#     * `.jpeg` / `.jpg`
#     * `.webp` (Investiguen esta, es la que más se usa hoy en web).
#     * `.svg`
# 2.  **Límites de GitHub:** Investiguen cuál es el tamaño máximo de un archivo que permite subir GitHub y cuánto es el límite total recomendado para un repositorio para no tener problemas de rendimiento.
#
# ---
#
# ## 🎨 Parte 3: Personalización (Tu toque personal)
#
# Ahora viene lo bueno:
# 1.  Creen una carpeta llamada `img` dentro de su proyecto.
# 2.  Busquen **9 imágenes propias** o de algún tema que les guste (hobbies, paisajes, viajes).
# 3.  Reemplacen los enlaces de ejemplo (los `src` de las etiquetas `img`) por las rutas locales de sus fotos (ejemplo: `src="img/mi-foto.jpg"`).
# 4.  **RETO EXTRA:** Agreguen un efecto de JavaScript para que, al hacer clic en una foto, salga un mensaje con el nombre de la imagen.
#
# ---
#
# ## 🚀 Entrega
#
# Para dar por finalizada la tarea, deben realizar el ciclo de Git que ya conocemos:
# 1.  `git add .`
# 2.  `git commit -m "Tarea: Mi galería personalizada finalizada"`
# 3.  `git push`
#
# **Me deben pasar el link de su GitHub Pages por el medio habitual.**
#
# ---
# *¡A darle átomos! Si tienen dudas con las rutas de las imágenes, me consultan.*
#
# ----------------------------------------------------------------------------------------------------
#
# # 27/03/2026
#
# # 📝 Tarea: El Desafío del Arquitecto Web (IA + Código)
# **Fecha:** 27 de marzo de 2026
# **Docente:** Pol Monsalvo
#
# Como ya dominan la creación de archivos HTML/CSS, el **Vibe Coding** y el flujo de trabajo profesional con **Git** en la terminal de VS Code, hoy vamos a subir de nivel. El objetivo es que aprendan a usar la Inteligencia Artificial como un mentor técnico para construir su propia ruta de aprendizaje.
#
# ---
#
# ## 🎯 Instrucciones de la Tarea
#
# ### 1. Investigación con IA (Prompt Engineering)
# Deben consultar a distintas IAs (ChatGPT, Gemini, Claude) para obtener una **hoja de ruta (Roadmap)**. Copien y peguen este "Prompt Maestro" para obtener mejores resultados:
#
# > *"Actúa como un mentor experto en Frontend. Dame una lista de 5 a 8 proyectos de páginas web ordenados por dificultad (de nivel 0 a experto). Para cada proyecto, dime qué conceptos clave de HTML y CSS debo aprender (ej: Flexbox, Grid, Responsive, Animaciones, Pseudo-clases). Quiero una ruta clara para dominar el diseño web profesional."*
#
# ### 2. Réplica y Experimentación
# En su entorno local (VS Code):
# * Seleccionen los proyectos de la lista.
# * **Replíquenlos** uno por uno.
# * Utilicen la terminal para crear las carpetas y archivos necesarios.
# * Vean los resultados en tiempo real con **Live Server**.
#
# ### 3. Documentación Técnica (.md)
# Creen un archivo llamado `APRENDIZAJE.md` en su repositorio donde:
# * Enumeren los temas abordados (ej: "Hoy aprendí CSS Grid").
# * Expliquen brevemente para qué sirve cada concepto.
# * Suban este archivo a GitHub junto con el código de las prácticas.
#
# ### 4. Creación Original (El examen real)
# Una vez que entiendan los conceptos de la IA, deben crear **3 páginas web nuevas**:
# * **Temática:** Personal (Portfolio, Hobby, CV, Negocio propio).
# * **Requisito:** Deben aplicar lo aprendido en la ruta anterior pero con diseño y contenido **100% propio**. No se vale copiar el diseño de la IA aquí.
#
# ### 5. Entrega
# Al finalizar, realicen el `push` final a GitHub y envíen el link de su **GitHub Pages** al grupo de estudio de Diseño Web.
#
# ---
#
# ## 💡 Comandos Rápidos de Recordatorio
# Si se olvidan de los pasos en la terminal:
# 1. `git status` (Para ver qué cambió).
# 2. `git add .` (Para preparar los archivos).
# 3. `git commit -m "Logro: Finalizada página X de la ruta"` (Para guardar el progreso).
# 4. `git push` (Para subirlo a la nube).
#
#
# **¡A trabajar! Recuerden que la IA es una herramienta, pero el código lo entienden y lo dominan ustedes. ¡Éxitos!**
#
#
#
# ------------------------------------------------------------------------------------
#
#
#
# # 📑 Plantilla de Seguimiento: Mi Ruta de Aprendizaje Web
# **Alumno:** [Tu Nombre Aquí]
# **Fecha de inicio:** 27/03/2026
#
# Este documento sirve como bitácora de mi progreso desde nivel 0 hasta experto en Diseño Web Frontend.
#
# ---
#
# ## 🗺️ 1. Mi Hoja de Ruta (Roadmap)
# *Lista de proyectos sugeridos por la IA para dominar HTML y CSS:*
#
# 1.  **Nivel Inicial:** [Nombre del Proyecto 1]
# 2.  **Nivel Intermedio:** [Nombre del Proyecto 2]
# 3.  **Nivel Avanzado:** [Nombre del Proyecto 3]
# 4.  **Nivel Experto:** [Nombre del Proyecto 4]
#
# ---
#
# ## 🧠 2. Conceptos Técnicos Aprendidos
# *En esta sección documento qué aprendí en cada etapa:*
#
# ### 🔹 Maquetación y Estructura
# - [ ] **Semántica HTML5:** Uso correcto de `<main>`, `<article>`, `<aside>`, etc.
# - [ ] **Formularios Pro:** Validación de datos y tipos de `input`.
#
# ### 🔹 Estilos y Layouts (CSS)
# - [ ] **Flexbox:** Alineación de elementos en ejes.
# - [ ] **CSS Grid:** Creación de rejillas bidimensionales complejas.
# - [ ] **Variables CSS:** Uso de `--main-color` para sitios escalables.
#
#
#
# ### 🔹 Responsive Design (Adaptabilidad)
# - [ ] **Media Queries:** Cómo cambiar el diseño según el tamaño de pantalla.
# - [ ] **Mobile First:** Estrategia de diseño empezando por celulares.
#
# ---
#
# ## 🎨 3. Mis Proyectos Personales (Originales)
# *Aquí detallo las 3 páginas creadas desde cero aplicando lo aprendido:*
#
# 1.  **Proyecto A:** [Nombre/Descripción corta] - *Link de GitHub Pages:* [Insertar Link]
# 2.  **Proyecto B:** [Nombre/Descripción corta] - *Link de GitHub Pages:* [Insertar Link]
# 3.  **Proyecto C:** [Nombre/Descripción corta] - *Link de GitHub Pages:* [Insertar Link]
#
# ---
#
# ## 🛠️ 4. Comandos de Terminal Utilizados
# *Lista de comandos que domino en Bash/Git:*
# * `cd`: Navegar carpetas.
# * `ls`: Ver archivos.
# * `git commit -m "..."`: Guardar hitos.
#
# ---
#
# ### 💡 Instrucciones para el alumno:
# 1. Copia este contenido en tu archivo `README.md`.
# 2. A medida que completes un tema, marca la casilla cambiando `[ ]` por `[x]`.
# 3. No olvides hacer `git push` cada vez que actualices esta bitácora.

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# # 06/04/2026
#
#
#
# # 🏆 Gran Repaso: Todo lo que hemos logrado hasta hoy
#
# ### Módulo 1: Preparación del Entorno Profesional
# - [x] **Visual Studio Code:** Descarga, instalación y configuración del editor al idioma español.
# - [x] **Live Server:** Instalación y uso de la extensión para ver los cambios del código en el navegador en tiempo real.
# - [x] **Gestión de Carpetas:** Creación del espacio de trabajo (`mi-primer-proyecto`) y apertura correcta en el editor.
#
# ### Módulo 2: Dominio de la Terminal (Bash) y Git
# - [x] **Instalación de Git:** Descarga y configuración en el sistema operativo.
# - [x] **Comandos Bash Básicos:** Navegación y creación de archivos/carpetas sin usar el ratón (`pwd`, `ls`, `mkdir`, `touch`, `clear`).
# - [x] **Configuración de Identidad Git:** Uso de `git config` para establecer nombre y correo.
# - [x] **El Flujo de Trabajo Git:** Dominio del ciclo de vida del código local:
#   - `git init` (Inicializar)
#   - `git status` (Verificar cambios)
#   - `git add .` (Preparar archivos)
#   - `git commit -m "mensaje"` (Guardar historial)
# - [x] **GitHub y Despliegue:** Creación de repositorios en la nube, conexión del repositorio local remoto (`git remote add`), subida del código (`git push`) y publicación del sitio web en vivo a través de **GitHub Pages**.
#
# ### Módulo 3: Fundamentos de HTML5 (Estructura)
# - [x] **Etiquetas Semánticas y Básicas:** Uso de `<header>`, `<nav>`, `<main>`, `<section>`, `<footer>`.
# - [x] **Texto y Formato:** Títulos (`<h1>` a `<h6>`), párrafos (`<p>`), negritas (`<strong>`) y cursivas (`<em>`).
# - [x] **Navegación y Multimedia:** Creación de enlaces hipertexto (`<a>`) e inserción de imágenes (`<img>`).
# - [x] **Organización de Datos:** Creación de listas ordenadas (`<ol>`) y desordenadas (`<ul>`), e implementación de tablas estructuradas (`<table>`, `<tr>`, `<th>`, `<td>`).
# - [x] **Formularios Interactivos:** Creación de áreas de entrada de datos con `<form>`, `<input>` (texto, email, radio), `<textarea>` y botones `<button type="submit">`.
# - [x] **Contenido Embebido (Iframes):** Integración de videos de YouTube y mapas de Google Maps directamente en la página.
#
# ### Módulo 4: Diseño y Maquetación con CSS3
# - [x] **Separación de Lógica:** Transición de estilos en línea (`style="..."`) a hojas de estilo externas (`<link rel="stylesheet">`).
# - [x] **Estilos Globales:** Manipulación de fuentes, colores, fondos, márgenes y bordes.
# - [x] **Introducción a Flexbox:** Uso del Laboratorio Flexbox para entender la alineación moderna.
# - [x] **Control de Ejes:** Manejo de la dirección (`flex-direction: row/column`), alineación principal (`justify-content`) y alineación cruzada (`align-items`).
# - [x] **Comportamiento Responsivo Básico:** Uso de `flex-wrap` para que los elementos fluyan a la siguiente línea si no hay espacio.
#
# ### Módulo 5: Interactividad "Modo Dios" con JavaScript
# - [x] **Vinculación:** Conexión del archivo `script.js` al final del HTML.
# - [x] **Manipulación del DOM:** Selección de elementos (`querySelector`, `getElementById`) e inserción de nuevos elementos creados desde cero (`createElement`, `appendChild`).
# - [x] **Manejo de Eventos:** Detección de clics (`click`), movimientos del ratón (`mouseenter`, `mouseleave`, `mousemove`), tipeo en inputs (`input`) y envío de formularios (`submit`).
# - [x] **Lógica y Alertas:** Prevención del recargo de página (`e.preventDefault()`), validación de campos vacíos, uso de variables y *Template Literals* para mensajes personalizados.
# - [x] **Efectos Visuales Avanzados:** Creación de estelas de colores al mover el ratón, animaciones matemáticas usando el Seno (`Math.sin()`), cambios de color de fondo dinámicos y animaciones CSS controladas por JS (efecto "sacudida").
#
# ### Módulo 6: Gestión de Archivos y Límites Técnicos
# - [x] **Teoría de Extensiones Multimedia:** Investigación y comprensión de las diferencias y casos de uso para formatos como `.png`, `.jpeg/.jpg`, `.webp` y `.svg`.
# - [x] **Infraestructura y Límites:** Averiguación sobre los tamaños máximos de archivos individuales y los límites de almacenamiento recomendados en los repositorios de GitHub.
# - [x] **Práctica de Galería:** Reemplazo de imágenes online por rutas locales (carpetas `img/`) en una galería Flexbox real.
#
# ### Módulo 7: Inteligencia Artificial, Vibe Coding y Documentación
# - [x] **Prompt Engineering:** Formulación de comandos efectivos a IAs (ChatGPT, Gemini) para generar rutas de aprendizaje ("Roadmaps") de nivel 0 a experto.
# - [x] **Implementación Práctica:** Replicación técnica en VS Code del código generado por las IAs para entender conceptos nuevos.
# - [x] **Autonomía y Personalización:** Desarrollo de **3 páginas web totalmente personalizadas** (diseño y contenido propio) aplicando los conceptos de la ruta dictada por la IA.
# - [x] **Documentación Profesional:** Creación y mantenimiento de archivos Markdown (`README.md` y `APRENDIZAJE.md`) con listas de verificación (`[ ]`) para hacer un seguimiento del progreso teórico y listar comandos de terminal útiles.
